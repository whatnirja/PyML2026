# %% [markdown]
# # Introduction to deep learning for computer vision

# %% [markdown]
# ## Import packages

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ## Import MNIST DataSet

# %%
from tensorflow.keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# **Do some sanity check on the data**
# - what is the shape of train and test set and the corresponding labels?
# - How many data points are there in train and test set?
# - What is the range of labels? Are they one hot encoded or they are just numbers?
# - Print a sample data point from train
# - show the sample datapoint with `imshow` (pass cmap="gray" argument to see the image in black and white)

# %%
#TODO: your sanity checks for imported dataset
# Shape of datasets
print("Train images shape:", train_images.shape)
print("Train labels shape:", train_labels.shape)

print("Test images shape:", test_images.shape)
print("Test labels shape:", test_labels.shape)

# Number of data points
print("Number of training samples:", train_images.shape[0])
print("Number of test samples:", test_images.shape[0])
# Out:
# Train images shape: (60000, 28, 28)
# Train labels shape: (60000,)
# Test images shape: (10000, 28, 28)
# Test labels shape: (10000,)
# Number of training samples: 60000
# Number of test samples: 10000

# %% [markdown]
# ## Data preprocessing

# %%
# Reshape the training images to have a shape of (60000, 28, 28, 1),
# where 60000 is the number of images,
# 28x28 is the image size,
# and 1 represents the single color channel (grayscale).
train_images = train_images.reshape((60000, 28, 28, 1))

# Convert pixel values from integers (0-255) to floating-point numbers (0.0-1.0)
# for better model performance.
train_images = train_images.astype("float32") / 255

test_images = test_images.reshape((10000, 28, 28, 1))

test_images = test_images.astype("float32") / 255

# %% [markdown]
# ## Part A: Introduction to convnets

# %% [markdown]
# **Visualizing the conv operarion 3-chanel images**
# - image size = (5 x 5 x 3)
# - kernel_size = 3
# - stride = 1
# - padding = no padding

# %%
from IPython.display import display, HTML

gif_url = "https://raw.githubusercontent.com/PyDataGBC/PyML2025/main/LabWeek11/assets/Conv2d_0p_1s_3inCh.gif"
display(HTML(f'<img src="{gif_url}" width="600" height="400">'))  # Adjust size as needed
# Out:
# <img src="https://raw.githubusercontent.com/PyDataGBC/PyML2025/main/LabWeek11/assets/Conv2d_0p_1s_3inCh.gif" width="600" height="400">

# %% [markdown]
# **Instantiating a small convnet**

# %% [markdown]
# ![](https://raw.githubusercontent.com/PyDataGBC/PyML2025/refs/heads/main/LabWeek11/assets/image.png)

# %% [markdown]
# **Note:** Suppose $n1=32$ and $n2=64$

# %% [markdown]
# **We can instantiate the model in TensorFlow in two ways.**

# %% [markdown]
# **Approach 1: Sequential API**

# %%
from keras import layers
from keras import models

model = models.Sequential()
model.add(layers.Input(shape=(28, 28, 1)))
model.add(layers.Conv2D(32, (5, 5), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (5, 5), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dense(10, activation='softmax'))

# %% [markdown]
# **Approach 2: Functioanl API**
# - In Keras' functional API, each layer acts like a function that transforms an `input` tensor.
# - When you pass inputs through multiple layers, Keras records the entire sequence of transformations.
# - `model = keras.Model(inputs, outputs)` connects the dots, forming a complete model from `inputs` to `outputs`.

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = layers.Input(shape=(28, 28, 1), name="input_layer")

x = layers.Conv2D(32, 5, activation="relu", name="conv1")(inputs)
x = layers.MaxPooling2D(2, name="pool1")(x)

conv_2 = layers.Conv2D(64, 5, activation="relu", name="conv2")(x)
x = layers.MaxPooling2D(2, name="pool2")(conv_2)

x = layers.Flatten(name="flatten")(x)
outputs = layers.Dense(10, activation="softmax", name="output")(x)

model = keras.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# Sequential API is easier however with functioal API non-Sequential Connections Allowed:
#
# - You can create models with branches, residual connections (like ResNet), or multi-input/multi-output structures.
#
# - You can access intermediate output.
#
# ```python
# model.get_layer("conv1").output
# ```
#
# - creat sub-models
# ```python
# intermediate_model = keras.Model(
#     inputs=inputs, #our model has one input branch
#     outputs=conv_2
# )
# ```

# %% [markdown]
# **Displaying the model's summary**

# %%
model.summary()
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1 (Conv2D)                  │ (None, 24, 24, 32)     │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool1 (MaxPooling2D)            │ (None, 12, 12, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2 (Conv2D)                  │ (None, 8, 8, 64)       │        51,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool2 (MaxPooling2D)            │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 10)             │        10,250 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 62,346 (243.54 KB)
#  Trainable params: 62,346 (243.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Instantiate your own model with the following architecture and then display the summary of the model**
#
# - Input layer
# - Conv2D with `filter`=32 and `kernel_size`=3
# - MaxPooling2d with `pool_size`=2
# - Conv2D with `filter`=64 and `kernel_size`=3
# - MaxPooling2d with `pool_size`=2
# - Conv2D with `filter`=128 and `kernel_size`=3
# - Flatten layer
# - Output layer (for 10 classes)
#
# **Note:** Use functioal API to define your model

# %%
#your code here
inputs = layers.Input(shape=(28, 28, 1), name="input_layer")

x = layers.Conv2D(32, (3, 3), activation="relu", name="conv1")(inputs)
x = layers.MaxPooling2D((2, 2), name="pool1")(x)

x = layers.Conv2D(64, (3, 3), activation="relu", name="conv2")(x)
x = layers.MaxPooling2D((2, 2), name="pool2")(x)

x = layers.Conv2D(128, (3, 3), activation="relu", name="conv3")(x)

x = layers.Flatten(name="flatten")(x)
outputs = layers.Dense(10, activation="softmax", name="output")(x)

model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1 (Conv2D)                  │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool1 (MaxPooling2D)            │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2 (Conv2D)                  │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool2 (MaxPooling2D)            │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3 (Conv2D)                  │ (None, 3, 3, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 10)             │        11,530 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 104,202 (407.04 KB)
#  Trainable params: 104,202 (407.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Compiling and Training the convnet on MNIST images**
#
# **Note 1:** Use `loss="sparse_categorical_crossentropy"`
#
# **Note 2:** Train for 5 `epochs` with `batch_size`=64

# %%
#your code here
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)
history = model.fit(
    train_images,
    train_labels,
    epochs=5,
    batch_size=64
)
# Out:
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - accuracy: 0.9495 - loss: 0.1725
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9861 - loss: 0.0458
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9898 - loss: 0.0315
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9924 - loss: 0.0244
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9937 - loss: 0.0190

# %% [markdown]
# **Evaluating the convnet**

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9887 - loss: 0.0359
# Test accuracy: 0.989

# %% [markdown]
# ## Part B: Training a convnet from scratch on a small dataset

# %% [markdown]
# **In this [Kaggle competition](https://www.kaggle.com/c/dogs-vs-cats/overview), you'll write an algorithm to classify whether images contain either a dog or a cat (binary classification - 0: Cat, 1: Dog).**
#
# **Try to get the accuracy above 80%**

# %% [markdown]
# ### Downloading the data

# %%
## Download a zip with a subset of the cats and dogs from Gootl Drive
# !gdown 1HxDoufgbF11R_xPfFmdXLnfztPXYaKiS
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1HxDoufgbF11R_xPfFmdXLnfztPXYaKiS
# From (redirected): https://drive.google.com/uc?id=1HxDoufgbF11R_xPfFmdXLnfztPXYaKiS&confirm=t&uuid=41157c7a-4dc0-4361-bc0f-597d386a56cb
# To: /content/catsVdogs_small.zip
# 100% 114M/114M [00:00<00:00, 184MB/s]

# %%
# !unzip -o -q catsVdogs_small.zip

# %% [markdown]
# ### Data preprocessing (For this section just run the cells)

# %% [markdown]
# **Copying images to training, validation, and test directories**

# %%
# imports and setup
import os, shutil, pathlib
from tensorflow.keras.utils import image_dataset_from_directory

new_base_dir = pathlib.Path('small')

# %%
train_dataset = image_dataset_from_directory(
    new_base_dir / "train",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    new_base_dir / "test",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %% [markdown]
# ### Displaying the the data and labels yielded by the `Dataset`

# %% [markdown]
# `train_dataset`, `validation_dataset`, and `test_dataset` behave like a **generator** in the sense that it **yields data lazily** when iterated over, instead of loading everything into memory at once.

# %%
for data_batch, labels_batch in train_dataset:
    print("data batch shape:", data_batch.shape)
    print("labels batch shape:", labels_batch.shape)
    sample_batch = data_batch
    sample_labels = labels_batch
    break # break the for-loop because we just want one batch
# Out:
# data batch shape: (32, 180, 180, 3)
# labels batch shape: (32,)

# %% [markdown]
# **Explain each element of the data batch shape tuple**

# %% [markdown]
# your answer:
#
# - 32 → number of images in one batch (batch size)
# - 180, 180 → image height and width
# - 3 → number of color channels (RGB)

# %%
print("label", sample_labels[10])
plt.imshow(sample_batch[10].numpy().astype("uint8"))
# Out:
# label tf.Tensor(1, shape=(), dtype=int32)

# %% [markdown]
# **TODO: Visualize some other samples from the batch with their corresponding labels.**

# %%
#your code here

plt.figure(figsize=(10, 10))

for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.imshow(sample_batch[i].numpy().astype("uint8"))
    plt.title(f"Label: {sample_labels[i]}")
    plt.axis("off")

plt.show()

# %% [markdown]
# ### Building the model

# %% [markdown]
# **Instantiating a small convnet for dogs vs. cats classification**

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)

#TODO: Add here a Conv2D with filters=64, kernel_size=3
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
#TODO: Add here MaxPooling2d
x = layers.MaxPool2D(pool_size=2)(x)

x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 178, 178, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 89, 89, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 87, 87, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 43, 43, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 41, 41, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 20, 20, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 18, 18, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 9, 9, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 7, 7, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 12544)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │        12,545 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 991,041 (3.78 MB)
#  Trainable params: 991,041 (3.78 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Compile the model**

# %% [markdown]
# Compile the model for the binary classification task.
#
# **Note:** Make sure you pass `metrics=["accuracy"]` as an argument. Otherwise you get error when you plot the history.

# %%
from flax.nnx import optimizer
# your code here
model.compile(
    optimizer="rmsprop",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %% [markdown]
# **Train the model using a `Dataset`**

# %%
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    # callbacks=callbacks
    )
# Out:
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 15s 142ms/step - accuracy: 0.5305 - loss: 0.7078 - val_accuracy: 0.5240 - val_loss: 0.6920
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 0.5185 - loss: 0.6938 - val_accuracy: 0.5110 - val_loss: 0.6902
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.5755 - loss: 0.6823 - val_accuracy: 0.5170 - val_loss: 0.6856
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.6325 - loss: 0.6506 - val_accuracy: 0.5970 - val_loss: 0.6679
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.6655 - loss: 0.6022 - val_accuracy: 0.6520 - val_loss: 0.6311
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.6795 - loss: 0.5959 - val_accuracy: 0.6560 - val_loss: 0.6048
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - accuracy: 0.7240 - loss: 0.5626 - val_accuracy: 0.6670 - val_loss: 0.6087
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.7315 - loss: 0.5519 - val_accuracy: 0.6530 - val_loss: 0.6324
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.7625 - loss: 0.5057 - val_accuracy: 0.6800 - val_loss: 0.6118
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.7825 - loss: 0.4701 - val_accuracy: 0.6980 - val_loss: 0.6410
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.8075 - loss: 0.4175 - val_accuracy: 0.6870 - val_loss: 0.7073
# Epoch 12/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.8395 - loss: 0.3773 - val_accuracy: 0.6880 - val_loss: 1.1707
# Epoch 13/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.8580 - loss: 0.3212 - val_accuracy: 0.7250 - val_loss: 0.6310
# Epoch 14/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.8950 - loss: 0.2580 - val_accuracy: 0.7370 - val_loss: 0.8307
# Epoch 15/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 86ms/step - accuracy: 0.9085 - loss: 0.2307 - val_accuracy: 0.7410 - val_loss: 0.7700
# Epoch 16/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9280 - loss: 0.1827 - val_accuracy: 0.7370 - val_loss: 0.9376
# Epoch 17/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.9410 - loss: 0.1655 - val_accuracy: 0.6720 - val_loss: 0.9874
# Epoch 18/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.9530 - loss: 0.1232 - val_accuracy: 0.7130 - val_loss: 1.2416
# Epoch 19/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.9685 - loss: 0.0925 - val_accuracy: 0.6550 - val_loss: 1.6230
# Epoch 20/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - accuracy: 0.9685 - loss: 0.0890 - val_accuracy: 0.7260 - val_loss: 1.4890
# Epoch 21/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.9750 - loss: 0.0699 - val_accuracy: 0.7160 - val_loss: 1.6033
# Epoch 22/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.9720 - loss: 0.0866 - val_accuracy: 0.7080 - val_loss: 1.9008
# Epoch 23/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.9775 - loss: 0.0740 - val_accuracy: 0.7230 - val_loss: 1.6824
# Epoch 24/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.9760 - loss: 0.0875 - val_accuracy: 0.7100 - val_loss: 1.5709
# Epoch 25/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.9825 - loss: 0.0483 - val_accuracy: 0.7150 - val_loss: 2.0857
# Epoch 26/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9860 - loss: 0.0489 - val_accuracy: 0.6910 - val_loss: 2.3296
# Epoch 27/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.9815 - loss: 0.0729 - val_accuracy: 0.7430 - val_loss: 1.7894
# Epoch 28/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - accuracy: 0.9880 - loss: 0.0611 - val_accuracy: 0.7390 - val_loss: 1.8691
# Epoch 29/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9885 - loss: 0.0437 - val_accuracy: 0.6950 - val_loss: 3.0895
# Epoch 30/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9760 - loss: 0.0678 - val_accuracy: 0.7310 - val_loss: 2.2612

# %% [markdown]
# **Displaying curves of loss and accuracy during training**

# %%
import matplotlib.pyplot as plt
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# **Evaluating the model on the test set**

# %%
#TODO: Evaluate the model
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.4950 - loss: 0.6931
# Test accuracy: 0.495

# %% [markdown]
# - **What is your test accuracy?**
# test accuracy: 49.5%
#
# - **Does you model overfit?**
# Yes, the model overfits because the training accuracy (97.6%) is much higher than the validation accuracy (73.1%) and test accuracy (49.5%). This indicates that the model learned the training data well but fails to generalize to unseen data.

# %% [markdown]
# You can use **regularization** or **dropout** to address overfitting. **Data augmentation** is another technique that introduces variation into your data and effectively increases the number of data points.

# %% [markdown]
# ### Using data augmentation

# %% [markdown]
# **Define a data augmentation stage to add to an image model**

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
    ]
)

# %% [markdown]
# **Displaying some randomly augmented training images**

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_dataset:
    image = images[0:1]
    for i in range(9):
        augmented_image = data_augmentation(image)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_image[0].numpy().astype("uint8"))
        plt.axis("off")
    break

# %% [markdown]
# **Defining a new convnet that includes image augmentation and dropout**

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)         #This line is new - changes the batch randomly through augmentation
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)            #This line is new - to prevent overfitting
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# **Training the regularized convnet**

# %% [markdown]
# Train the new model for 100 epochs.

# %%
#your code here
history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset
)
# Out:
# Epoch 1/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - accuracy: 0.5055 - loss: 0.7003 - val_accuracy: 0.6200 - val_loss: 0.6918
# Epoch 2/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.5315 - loss: 0.6901 - val_accuracy: 0.5640 - val_loss: 0.6817
# Epoch 3/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.5930 - loss: 0.6779 - val_accuracy: 0.5990 - val_loss: 0.6523
# Epoch 4/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.6095 - loss: 0.6566 - val_accuracy: 0.6090 - val_loss: 0.6617
# Epoch 5/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.6270 - loss: 0.6391 - val_accuracy: 0.6010 - val_loss: 0.6548
# Epoch 6/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.6470 - loss: 0.6259 - val_accuracy: 0.5950 - val_loss: 0.6450
# Epoch 7/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.6815 - loss: 0.6079 - val_accuracy: 0.6000 - val_loss: 0.6401
# Epoch 8/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.6670 - loss: 0.6090 - val_accuracy: 0.6360 - val_loss: 0.6210
# Epoch 9/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.6800 - loss: 0.5879 - val_accuracy: 0.6650 - val_loss: 0.5957
# Epoch 10/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.6935 - loss: 0.5847 - val_accuracy: 0.6650 - val_loss: 0.6406
# Epoch 11/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.6830 - loss: 0.5862 - val_accuracy: 0.7000 - val_loss: 0.5677
# Epoch 12/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.7115 - loss: 0.5572 - val_accuracy: 0.7100 - val_loss: 0.5572
# Epoch 13/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.7170 - loss: 0.5553 - val_accuracy: 0.6920 - val_loss: 0.5731
# Epoch 14/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.7175 - loss: 0.5475 - val_accuracy: 0.6930 - val_loss: 0.5898
# Epoch 15/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.7420 - loss: 0.5222 - val_accuracy: 0.7110 - val_loss: 0.5623
# Epoch 16/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.7515 - loss: 0.5245 - val_accuracy: 0.7240 - val_loss: 0.5339
# Epoch 17/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.7315 - loss: 0.5241 - val_accuracy: 0.7550 - val_loss: 0.4936
# Epoch 18/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.7565 - loss: 0.5109 - val_accuracy: 0.7440 - val_loss: 0.5060
# Epoch 19/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.7680 - loss: 0.4897 - val_accuracy: 0.7790 - val_loss: 0.4715
# Epoch 20/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.7585 - loss: 0.4801 - val_accuracy: 0.7090 - val_loss: 0.5917
# Epoch 21/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.7655 - loss: 0.4786 - val_accuracy: 0.7680 - val_loss: 0.5085
# Epoch 22/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.7830 - loss: 0.4682 - val_accuracy: 0.7280 - val_loss: 0.5330
# Epoch 23/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.7835 - loss: 0.4756 - val_accuracy: 0.7690 - val_loss: 0.4826
# Epoch 24/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.7920 - loss: 0.4408 - val_accuracy: 0.7230 - val_loss: 0.7032
# Epoch 25/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.7975 - loss: 0.4543 - val_accuracy: 0.7540 - val_loss: 0.4936
# Epoch 26/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.8130 - loss: 0.4182 - val_accuracy: 0.8050 - val_loss: 0.4360
# Epoch 27/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.8030 - loss: 0.4124 - val_accuracy: 0.7870 - val_loss: 0.4592
# Epoch 28/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.8105 - loss: 0.4039 - val_accuracy: 0.8020 - val_loss: 0.4469
# Epoch 29/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.8215 - loss: 0.4031 - val_accuracy: 0.7700 - val_loss: 0.5156
# Epoch 30/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.8235 - loss: 0.3885 - val_accuracy: 0.7550 - val_loss: 0.5970
# Epoch 31/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - accuracy: 0.8325 - loss: 0.3888 - val_accuracy: 0.7930 - val_loss: 0.4346
# Epoch 32/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.8295 - loss: 0.3876 - val_accuracy: 0.8000 - val_loss: 0.4544
# Epoch 33/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.8390 - loss: 0.3692 - val_accuracy: 0.7950 - val_loss: 0.5375
# Epoch 34/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.8395 - loss: 0.3536 - val_accuracy: 0.8080 - val_loss: 0.4427
# Epoch 35/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.8480 - loss: 0.3546 - val_accuracy: 0.8080 - val_loss: 0.4351
# Epoch 36/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.8575 - loss: 0.3525 - val_accuracy: 0.8330 - val_loss: 0.3898
# Epoch 37/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.8600 - loss: 0.3217 - val_accuracy: 0.8090 - val_loss: 0.4464
# Epoch 38/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.8610 - loss: 0.3227 - val_accuracy: 0.7970 - val_loss: 0.5370
# Epoch 39/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 84ms/step - accuracy: 0.8480 - loss: 0.3410 - val_accuracy: 0.7950 - val_loss: 0.4612
# Epoch 40/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.8645 - loss: 0.3323 - val_accuracy: 0.8260 - val_loss: 0.4276
# Epoch 41/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.8710 - loss: 0.2980 - val_accuracy: 0.7930 - val_loss: 0.5504
# Epoch 42/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - accuracy: 0.8795 - loss: 0.2964 - val_accuracy: 0.7970 - val_loss: 0.5247
# Epoch 43/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.8780 - loss: 0.2926 - val_accuracy: 0.8310 - val_loss: 0.4036
# Epoch 44/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.8805 - loss: 0.2883 - val_accuracy: 0.8220 - val_loss: 0.4123
# Epoch 45/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - accuracy: 0.8860 - loss: 0.2848 - val_accuracy: 0.8230 - val_loss: 0.4334
# Epoch 46/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.8740 - loss: 0.2843 - val_accuracy: 0.8280 - val_loss: 0.4287
# Epoch 47/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.8780 - loss: 0.2705 - val_accuracy: 0.8200 - val_loss: 0.5225
# Epoch 48/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.8900 - loss: 0.2724 - val_accuracy: 0.8110 - val_loss: 0.4856
# Epoch 49/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.8990 - loss: 0.2488 - val_accuracy: 0.8330 - val_loss: 0.4398
# Epoch 50/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.8995 - loss: 0.2551 - val_accuracy: 0.8170 - val_loss: 0.4491
# Epoch 51/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.9000 - loss: 0.2462 - val_accuracy: 0.8140 - val_loss: 0.5730
# Epoch 52/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 57ms/step - accuracy: 0.8980 - loss: 0.2465 - val_accuracy: 0.8020 - val_loss: 0.5249
# Epoch 53/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.8945 - loss: 0.2508 - val_accuracy: 0.8270 - val_loss: 0.5460
# Epoch 54/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - accuracy: 0.9160 - loss: 0.2381 - val_accuracy: 0.8380 - val_loss: 0.4774
# Epoch 55/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - accuracy: 0.9100 - loss: 0.2237 - val_accuracy: 0.7820 - val_loss: 0.7879
# Epoch 56/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9095 - loss: 0.2221 - val_accuracy: 0.8310 - val_loss: 0.4956
# Epoch 57/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - accuracy: 0.9000 - loss: 0.2322 - val_accuracy: 0.8290 - val_loss: 0.4529
# Epoch 58/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9125 - loss: 0.2146 - val_accuracy: 0.8170 - val_loss: 0.5073
# Epoch 59/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.9050 - loss: 0.2359 - val_accuracy: 0.8480 - val_loss: 0.4673
# Epoch 60/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9195 - loss: 0.2069 - val_accuracy: 0.8310 - val_loss: 0.5899
# Epoch 61/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9110 - loss: 0.2225 - val_accuracy: 0.8150 - val_loss: 0.6892
# Epoch 62/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.9180 - loss: 0.2072 - val_accuracy: 0.8300 - val_loss: 0.4990
# Epoch 63/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9195 - loss: 0.2041 - val_accuracy: 0.8130 - val_loss: 0.5335
# Epoch 64/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - accuracy: 0.9170 - loss: 0.2123 - val_accuracy: 0.8060 - val_loss: 0.8368
# Epoch 65/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9250 - loss: 0.1919 - val_accuracy: 0.8430 - val_loss: 0.5234
# Epoch 66/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.9305 - loss: 0.1821 - val_accuracy: 0.8130 - val_loss: 0.5826
# Epoch 67/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9200 - loss: 0.1843 - val_accuracy: 0.7950 - val_loss: 0.5406
# Epoch 68/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.9335 - loss: 0.1779 - val_accuracy: 0.8320 - val_loss: 0.7435
# Epoch 69/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.9245 - loss: 0.2046 - val_accuracy: 0.8430 - val_loss: 0.5225
# Epoch 70/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.9240 - loss: 0.2026 - val_accuracy: 0.8400 - val_loss: 0.5457
# Epoch 71/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.9310 - loss: 0.1977 - val_accuracy: 0.8560 - val_loss: 0.5525
# Epoch 72/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.9330 - loss: 0.1864 - val_accuracy: 0.8390 - val_loss: 0.5328
# Epoch 73/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9375 - loss: 0.1492 - val_accuracy: 0.7960 - val_loss: 0.7133
# Epoch 74/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.9300 - loss: 0.1655 - val_accuracy: 0.8440 - val_loss: 0.5566
# Epoch 75/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.9350 - loss: 0.1811 - val_accuracy: 0.8390 - val_loss: 0.5777
# Epoch 76/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9395 - loss: 0.1693 - val_accuracy: 0.8480 - val_loss: 0.4959
# Epoch 77/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.9425 - loss: 0.1661 - val_accuracy: 0.8380 - val_loss: 0.5924
# Epoch 78/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.9365 - loss: 0.1675 - val_accuracy: 0.8580 - val_loss: 0.5757
# Epoch 79/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9310 - loss: 0.1940 - val_accuracy: 0.8560 - val_loss: 0.4731
# Epoch 80/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 81ms/step - accuracy: 0.9305 - loss: 0.1736 - val_accuracy: 0.8650 - val_loss: 0.5398
# Epoch 81/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9435 - loss: 0.1622 - val_accuracy: 0.8590 - val_loss: 0.5223
# Epoch 82/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.9485 - loss: 0.1515 - val_accuracy: 0.8400 - val_loss: 0.5667
# Epoch 83/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9505 - loss: 0.1473 - val_accuracy: 0.8430 - val_loss: 0.5537
# Epoch 84/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - accuracy: 0.9390 - loss: 0.1588 - val_accuracy: 0.8500 - val_loss: 0.6421
# Epoch 85/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.9380 - loss: 0.1775 - val_accuracy: 0.8330 - val_loss: 0.7427
# Epoch 86/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - accuracy: 0.9440 - loss: 0.1511 - val_accuracy: 0.8400 - val_loss: 0.5377
# Epoch 87/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9465 - loss: 0.1479 - val_accuracy: 0.8580 - val_loss: 0.5428
# Epoch 88/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9395 - loss: 0.1650 - val_accuracy: 0.8420 - val_loss: 0.5466
# Epoch 89/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.9450 - loss: 0.1455 - val_accuracy: 0.8240 - val_loss: 0.5121
# Epoch 90/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.9485 - loss: 0.1387 - val_accuracy: 0.8430 - val_loss: 0.6788
# Epoch 91/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.9475 - loss: 0.1480 - val_accuracy: 0.8680 - val_loss: 0.5643
# Epoch 92/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.9485 - loss: 0.1586 - val_accuracy: 0.8370 - val_loss: 0.6084
# Epoch 93/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 53ms/step - accuracy: 0.9500 - loss: 0.1466 - val_accuracy: 0.8430 - val_loss: 0.6649
# Epoch 94/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.9420 - loss: 0.1651 - val_accuracy: 0.8340 - val_loss: 0.8047
# Epoch 95/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9505 - loss: 0.1610 - val_accuracy: 0.8480 - val_loss: 0.5268
# Epoch 96/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9450 - loss: 0.1614 - val_accuracy: 0.8390 - val_loss: 0.5981
# Epoch 97/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.9480 - loss: 0.1480 - val_accuracy: 0.8480 - val_loss: 0.6915
# Epoch 98/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.9470 - loss: 0.1413 - val_accuracy: 0.8210 - val_loss: 0.7800
# Epoch 99/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9500 - loss: 0.1416 - val_accuracy: 0.8360 - val_loss: 0.9190
# Epoch 100/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 58ms/step - accuracy: 0.9545 - loss: 0.1463 - val_accuracy: 0.8480 - val_loss: 0.5055

# %% [markdown]
# **Plot curves of loss and accuracy during training**

# %%
#your code here
accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]

epochs = range(1, len(accuracy) + 1)

plt.plot(epochs, accuracy, "bo", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()

plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %% [markdown]
# **Evaluating the model on the test set**

# %%
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.8585 - loss: 0.5585
# Test accuracy: 0.859

# %% [markdown]
# **What is your test accuracy after using data augmentation and dropout?**

# %% [markdown]
# your answer: Test accuracy after using data augmentation and dropout: 0.859 (85.9%)
